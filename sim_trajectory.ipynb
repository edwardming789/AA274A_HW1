# %% [markdown]
# # Trajectory Optimization and Tracking Simulation
#
# In this notebook, we will run the trajectory optimization code from Problem 1 as well as the trajectory tracking code from Problem 3.

# %%
# The autoreload extension will automatically load in new code as you edit files, 
# so you don't need to restart the kernel every time
# %load_ext autoreload
# %autoreload 2
import numpy as np
from matplotlib import pyplot as plt
from utils import simulate_car_dyn, maybe_makedirs
from P1_differential_flatness import State, compute_traj_coeffs, compute_traj_with_limits 
from P3_trajectory_tracking import TrajectoryTracker

maybe_makedirs('plots')

# %% [markdown]
# ### Various constants
# (Try changing these and seeing what happens)

# %%
V_max = 0.5 # max speed
om_max = 1 # max rotational speed
tf  = 15 # final time (sec)
N = 301 # number of timesteps
dt = tf*1./(N-1)

# %% [markdown]
# ### Starting and Final States
# (Try changing these and seeing what happens)

# %%
s_0 = State(x=0, y=0, V=V_max, th=-np.pi/2)
s_f = State(x=5, y=5, V=V_max, th=-np.pi/2)

# %% [markdown]
# # Trajectory Optimization
# First, we will use the implementations from problem 1 to compute a dynamically feasible trajectory from the starting point to the goal.

# %%
traj, tau, V_tilde, om_tilde = compute_traj_with_limits(s_0, s_f, tf, N, V_max, om_max)
# Out:
# [0.5        0.48343455 0.46707671 0.45093491 0.43501864 0.41933856
#  0.40390672 0.3887367  0.37384389 0.35924572 0.34496198 0.33101512
#  0.31743069 0.30423766 0.29146892 0.27916169 0.26735793 0.2561047
#  0.24545435 0.23546453 0.22619777 0.21772067 0.21010233 0.20341212
#  0.19771656 0.19307554 0.18953807 0.18713816 0.18589132 0.18579245
#  0.18681542 0.18891461 0.192028   0.19608134 0.20099264 0.20667656
#  0.21304798 0.22002482 0.22752999 0.23549244 0.24384776 0.25253815
#  0.26151222 0.27072455 0.28013515 0.28970891 0.29941503 0.30922654
#  0.31911979 0.32907401 0.33907099 0.34909467 0.35913092 0.36916726
#  0.37919262 0.3891972  0.39917229 0.40911012 0.41900375 0.42884699
#  0.43863424 0.44836052 0.45802131 0.46761254 0.47713053 0.48657192
#  0.49593371 0.50521311 0.51440762 0.52351494 0.53253296 0.54145977
#  0.55029359 0.55903281 0.56767591 0.57622153 0.58466839 0.59301531
#  0.60126121 0.60940507 0.61744595 0.62538299 0.63321538 0.64094235
#  0.64856321 0.6560773  0.663484   0.67078274 0.67797299 0.68505424
#  0.69202601 0.69888787 0.7056394  0.7122802  0.71880992 0.7252282
#  0.73153472 0.73772916 0.74381125 0.74978069 0.75563725 0.76138067
#  0.76701072 0.77252718 0.77792984 0.78321852 0.78839302 0.79345317
#  0.7983988  0.80322975 0.80794588 0.81254704 0.8170331  0.82140392
#  0.8256594  0.8297994  0.83382384 0.83773259 0.84152556 0.84520266
#  0.84876381 0.85220891 0.85553788 0.85875066 0.86184716 0.86482733
#  0.8676911  0.8704384  0.87306919 0.8755834  0.87798099 0.88026191
#  0.88242611 0.88447356 0.8864042  0.88821802 0.88991497 0.89149502
#  0.89295814 0.89430431 0.8955335  0.89664569 0.89764086 0.89851899
#  0.89928007 0.89992408 0.90045101 0.90086086 0.90115361 0.90132927
#  0.90138782 0.90132927 0.90115361 0.90086086 0.90045101 0.89992408
#  0.89928007 0.89851899 0.89764086 0.89664569 0.8955335  0.89430431
#  0.89295814 0.89149502 0.88991497 0.88821802 0.8864042  0.88447356
#  0.88242611 0.88026191 0.87798099 0.8755834  0.87306919 0.8704384
#  0.8676911  0.86482733 0.86184716 0.85875066 0.85553788 0.85220891
#  0.84876381 0.84520266 0.84152556 0.83773259 0.83382384 0.8297994
#  0.8256594  0.82140392 0.8170331  0.81254704 0.80794588 0.80322975
#  0.7983988  0.79345317 0.78839302 0.78321852 0.77792984 0.77252718
#  0.76701072 0.76138067 0.75563725 0.74978069 0.74381125 0.73772916
#  0.73153472 0.7252282  0.71880992 0.7122802  0.7056394  0.69888787
#  0.69202601 0.68505424 0.67797299 0.67078274 0.663484   0.6560773
#  0.64856321 0.64094235 0.63321538 0.62538299 0.61744595 0.60940507
#  0.60126121 0.59301531 0.58466839 0.57622153 0.56767591 0.55903281
#  0.55029359 0.54145977 0.53253296 0.52351494 0.51440762 0.50521311
#  0.49593371 0.48657192 0.47713053 0.46761254 0.45802131 0.44836052
#  0.43863424 0.42884699 0.41900375 0.40911012 0.39917229 0.3891972
#  0.37919262 0.36916726 0.35913092 0.34909467 0.33907099 0.32907401
#  0.31911979 0.30922654 0.29941503 0.28970891 0.28013515 0.27072455
#  0.26151222 0.25253815 0.24384776 0.23549244 0.22752999 0.22002482
#  0.21304798 0.20667656 0.20099264 0.19608134 0.192028   0.18891461
#  0.18681542 0.18579245 0.18589132 0.18713816 0.18953807 0.19307554
#  0.19771656 0.20341212 0.21010233 0.21772067 0.22619777 0.23546453
#  0.24545435 0.2561047  0.26735793 0.27916169 0.29146892 0.30423766
#  0.31743069 0.33101512 0.34496198 0.35924572 0.37384389 0.3887367
#  0.40390672 0.41933856 0.43501864 0.45093491 0.46707671 0.48343455
#  0.5       ]
# 301

# %%
plt.figure(figsize=[10,5])
plt.subplot(2,2,1)
plt.plot(tau, traj[:,:3])
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["x","y","th"])
plt.subplot(2,2,3)
plt.plot(tau, V_tilde)
plt.plot(tau, om_tilde)
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["V","om"])
plt.subplot(1,2,2)
plt.plot(traj[:,0], traj[:,1], color='k')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Simulation
# Next, we will simulate how well we can actually execute these trajectories in the presense of noise. We will make use of the `simulate_car_dyn` function to do the simulation. Take a look in `utils.py` to see what it's doing under the hood.

# %%
print(simulate_car_dyn.__doc__)
# Out:
#     inputs: x_0,y_0,th_0 (floats) initial state
#             times (list len N) sequence of times at which to apply control
#             controller: controller object to use to compute feedback control
#             actions: (np.array shape: N-1, 2) list of actions to apply
#             noise_scale: (float) standard deviation of control noise
#
#             if controller is provided, simulates feedback control by calling
#                 controller.compute_control(x,y,th,t) at each time step
#             otherwise, if the array actions is specified, they are applied open loop
#
#             (one of controller or actions must be specified)
#
#     outputs: states (np.array shape (N, 3)) sequence of [x,y,th] state vectors
#              ctrl (np.array shape (N-1, 2)) sequence of [V, om] control vectors

# %% [markdown]
# Choose a value of noise to apply at each step

# %%
noise_scale = np.sqrt(0.2)

# %% [markdown]
# ## Open Loop
# First, we simulate tracking this trajectory without any feedback control

# %%
actions_ol = np.stack([V_tilde, om_tilde], axis=-1)
states_ol, ctrl_ol = simulate_car_dyn(s_0.x, s_0.y, s_0.th, tau, actions=actions_ol, noise_scale=noise_scale)

# %%
plt.figure(figsize=[10,5])
plt.subplot(2,2,1)
plt.plot(tau, states_ol)
plt.plot(tau, traj[:,0], linestyle=':', color='C0', alpha=0.7)
plt.plot(tau, traj[:,1], linestyle=':', color='C1', alpha=0.7)
plt.plot(tau, traj[:,2], linestyle=':', color='C2', alpha=0.7)
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["x","y","th","nominal"])
plt.subplot(2,2,3)
plt.plot(tau[:-1], ctrl_ol)
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["V","om"])
plt.subplot(1,2,2)
plt.plot(states_ol[:,0], states_ol[:,1])
plt.plot(traj[:,0], traj[:,1], color="k", linestyle=":", alpha=0.7)
plt.legend(labels=["Open Loop", "Nominal"])
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.tight_layout()
plt.savefig("plots/sim_traj_openloop.pdf")
plt.show()

# %% [markdown]
# ## Closed Loop
# Next, we will use the tracking controller developed in problem 3 to apply feedback and track the trajectory in the presence of noise.

# %% [markdown]
# Try playing with these gains to see the impact on performance

# %%
kpx = 1.5
kpy = 1.5
kdx = 1.5
kdy = 2
controller = TrajectoryTracker(kpx=kpx, kpy=kpy, kdx=kdx, kdy=kdy, V_max=V_max, om_max=om_max)

# %% [markdown]
# This controller designed to be similar to the controller module you'll use on the real robots for the final project. You can think of it as a module that will track whatever trajectory is given to it from another module (e.g. a planner module). So the first step is to load the controller with the trajectory we have planned

# %%
controller.load_traj(tau, traj)

# %% [markdown]
# Then, we can simulate.

# %%
tf_actual = tau[-1]
times_cl = np.arange(0, tf_actual, dt)
states_cl, ctrl_cl = simulate_car_dyn(s_0.x, s_0.y, s_0.th, times_cl, controller=controller, noise_scale=noise_scale)

# %%
plt.figure(figsize=[10,5])
plt.subplot(2,2,1)
plt.plot(times_cl, states_cl)
plt.plot(tau, traj[:,0], linestyle=':', color='C0', alpha=0.7)
plt.plot(tau, traj[:,1], linestyle=':', color='C1', alpha=0.7)
plt.plot(tau, traj[:,2], linestyle=':', color='C2', alpha=0.7)
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["x","y","th","Nominal"])
plt.subplot(2,2,3)
plt.plot(times_cl[:-1], ctrl_cl)
plt.plot(tau[:-1], ctrl_ol[:,0], color='C0', linestyle=':', alpha=0.7)
plt.plot(tau[:-1], ctrl_ol[:,1], color='C1', linestyle=':', alpha=0.7)
plt.grid(True)
plt.xlabel('t')
plt.legend(labels=["V","om", "Nominal"])
plt.subplot(1,2,2)
plt.plot(traj[:,0], traj[:,1], color="k", linestyle=":", alpha=0.7)
plt.plot(states_ol[:,0], states_ol[:,1], alpha=0.7)
plt.plot(states_cl[:,0], states_cl[:,1])
plt.legend(labels=["Nominal", "Open Loop", "Closed Loop"])
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.tight_layout()
plt.savefig("plots/sim_traj_closedloop.pdf")
plt.show()
